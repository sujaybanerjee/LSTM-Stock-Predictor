# %%
# !pip install alpha_vantage

import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
import requests
from time import sleep
# Out:
# Collecting alpha_vantage
#   Downloading alpha_vantage-3.0.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (3.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->alpha_vantage) (4.12.2)
# Downloading alpha_vantage-3.0.0-py3-none-any.whl (35 kB)
# Installing collected packages: alpha_vantage
# Successfully installed alpha_vantage-3.0.0

# %%
# api_key_1 = 'KA4LIC1TXIS8RKYC'
# api_key_2 = 'E8J04H2JWSCENOKG'
# api_key_3 = '30B63PLFAA7F2C6K'
# api_key_4 = 'IL1S84LWPNAU5AZC'
# api_key_5 = 'FJUMLVR578JCX164'
# api_key_6 = 'LS3HW617Q3ZQ60U3'
# api_key_7 = 'M80WFUQ6UQP9MUOD'


# Define API keys for each sector
api_keys = {
    'Healthcare': 'M80WFUQ6UQP9MUOD',
    'Technology': 'E8J04H2JWSCENOKG',
    'Energy': '30B63PLFAA7F2C6K',
    'Consumer Staples': 'IL1S84LWPNAU5AZC',
    'Utilities': 'KA4LIC1TXIS8RKYC',
}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=IBM&apikey=KA4LIC1TXIS8RKYC'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Symbol': 'IBM', 'AssetType': 'Common Stock', 'Name': 'International Business Machines', 'Description': 'International Business Machines Corporation (IBM) is an American multinational technology company headquartered in Armonk, New York, with operations in over 170 countries. The company began in 1911, founded in Endicott, New York, as the Computing-Tabulating-Recording Company (CTR) and was renamed International Business Machines in 1924. IBM is incorporated in New York. IBM produces and sells computer hardware, middleware and software, and provides hosting and consulting services in areas ranging from mainframe computers to nanotechnology. IBM is also a major research organization, holding the record for most annual U.S. patents generated by a business (as of 2020) for 28 consecutive years. Inventions by IBM include the automated teller machine (ATM), the floppy disk, the hard disk drive, the magnetic stripe card, the relational database, the SQL programming language, the UPC barcode, and dynamic random-access memory (DRAM). The IBM mainframe, exemplified by the System/360, was the dominant computing platform during the 1960s and 1970s.', 'CIK': '51143', 'Exchange': 'NYSE', 'Currency': 'USD', 'Country': 'USA', 'Sector': 'TECHNOLOGY', 'Industry': 'COMPUTER & OFFICE EQUIPMENT', 'Address': '1 NEW ORCHARD ROAD, ARMONK, NY, US', 'OfficialSite': 'https://www.ibm.com', 'FiscalYearEnd': 'December', 'LatestQuarter': '2024-09-30', 'MarketCapitalization': '197615124000', 'EBITDA': '14676000000', 'PERatio': '31.15', 'PEGRatio': '7.08', 'BookValue': '26.44', 'DividendPerShare': '6.66', 'DividendYield': '0.0313', 'EPS': '6.86', 'RevenuePerShareTTM': '68.11', 'ProfitMargin': '0.102', 'OperatingMarginTTM': '0.141', 'ReturnOnAssetsTTM': '0.0473', 'ReturnOnEquityTTM': '0.267', 'RevenueTTM': '62579999000', 'GrossProfitTTM': '32688000000', 'DilutedEPSTTM': '6.86', 'QuarterlyEarningsGrowthYOY': '0.141', 'QuarterlyRevenueGrowthYOY': '0.015', 'AnalystTargetPrice': '213.65', 'AnalystRatingStrongBuy': '4', 'AnalystRatingBuy': '5', 'AnalystRatingHold': '10', 'AnalystRatingSell': '3', 'AnalystRatingStrongSell': '0', 'TrailingPE': '31.15', 'ForwardPE': '19.8', 'PriceToSalesRatioTTM': '3.158', 'PriceToBookRatio': '8.08', 'EVToRevenue': '3.9', 'EVToEBITDA': '19.29', 'Beta': '0.71', '52WeekHigh': '237.37', '52WeekLow': '143.33', '50DayMovingAverage': '218.02', '200DayMovingAverage': '191.14', 'SharesOutstanding': '924645000', 'DividendDate': '2024-09-10', 'ExDividendDate': '2024-11-12'}

# %% [markdown]
# # Create Datasets

# %%
companies = [
    # Healthcare Sector
    {'ticker': 'JNJ', 'name': 'Johnson & Johnson', 'sector': 'Healthcare'},
    {'ticker': 'UNH', 'name': 'UnitedHealth Group', 'sector': 'Healthcare'},
    {'ticker': 'PFE', 'name': 'Pfizer Inc.', 'sector': 'Healthcare'},
    {'ticker': 'MRK', 'name': 'Merck & Co.', 'sector': 'Healthcare'},
    {'ticker': 'ABBV', 'name': 'AbbVie Inc.', 'sector': 'Healthcare'},
    {'ticker': 'LLY', 'name': 'Eli Lilly and Co.', 'sector': 'Healthcare'},
    {'ticker': 'TMO', 'name': 'Thermo Fisher Scientific', 'sector': 'Healthcare'},
    {'ticker': 'ABT', 'name': 'Abbott Laboratories', 'sector': 'Healthcare'},
    {'ticker': 'BMY', 'name': 'Bristol-Myers Squibb', 'sector': 'Healthcare'},
    {'ticker': 'AMGN', 'name': 'Amgen Inc.', 'sector': 'Healthcare'},
    {'ticker': 'GILD', 'name': 'Gilead Sciences', 'sector': 'Healthcare'},
    {'ticker': 'NVO', 'name': 'Novo Nordisk', 'sector': 'Healthcare'},
    {'ticker': 'SNY', 'name': 'Sanofi-Aventis', 'sector': 'Healthcare'},
    {'ticker': 'VRTX', 'name': 'Vertex Pharmaceuticals', 'sector': 'Healthcare'},
    {'ticker': 'MDT', 'name': 'Medtronic PLC', 'sector': 'Healthcare'},

    # Technology Sector
    {'ticker': 'AAPL', 'name': 'Apple Inc.', 'sector': 'Technology'},
    {'ticker': 'MSFT', 'name': 'Microsoft Corporation', 'sector': 'Technology'},
    {'ticker': 'GOOGL', 'name': 'Alphabet Inc. (Class A)', 'sector': 'Technology'},
    {'ticker': 'GOOG', 'name': 'Alphabet Inc. (Class C)', 'sector': 'Technology'},
    {'ticker': 'AMZN', 'name': 'Amazon.com Inc.', 'sector': 'Technology'},
    {'ticker': 'META', 'name': 'Meta Platforms, Inc.', 'sector': 'Technology'},
    {'ticker': 'INTC', 'name': 'Intel Corporation', 'sector': 'Technology'},
    {'ticker': 'CSCO', 'name': 'Cisco Systems', 'sector': 'Technology'},
    {'ticker': 'NVDA', 'name': 'NVIDIA Corporation', 'sector': 'Technology'},
    {'ticker': 'ORCL', 'name': 'Oracle Corporation', 'sector': 'Technology'},
    {'ticker': 'ADBE', 'name': 'Adobe Inc.', 'sector': 'Technology'},
    {'ticker': 'CRM', 'name': 'Salesforce.com Inc.', 'sector': 'Technology'},
    {'ticker': 'IBM', 'name': 'IBM Corporation', 'sector': 'Technology'},
    {'ticker': 'TXN', 'name': 'Texas Instruments', 'sector': 'Technology'},
    {'ticker': 'AVGO', 'name': 'Broadcom Inc.', 'sector': 'Technology'},

    # Energy Sector
    {'ticker': 'XOM', 'name': 'Exxon Mobil Corporation', 'sector': 'Energy'},
    {'ticker': 'CVX', 'name': 'Chevron Corporation', 'sector': 'Energy'},
    {'ticker': 'COP', 'name': 'ConocoPhillips', 'sector': 'Energy'},
    {'ticker': 'SLB', 'name': 'Schlumberger Limited', 'sector': 'Energy'},
    {'ticker': 'EOG', 'name': 'EOG Resources', 'sector': 'Energy'},
    {'ticker': 'OXY', 'name': 'Occidental Petroleum', 'sector': 'Energy'},
    {'ticker': 'PSX', 'name': 'Phillips 66', 'sector': 'Energy'},
    {'ticker': 'MPC', 'name': 'Marathon Petroleum', 'sector': 'Energy'},
    {'ticker': 'VLO', 'name': 'Valero Energy', 'sector': 'Energy'},
    {'ticker': 'KMI', 'name': 'Kinder Morgan', 'sector': 'Energy'},
    {'ticker': 'HAL', 'name': 'Halliburton Company', 'sector': 'Energy'},
    {'ticker': 'DVN', 'name': 'Devon Energy', 'sector': 'Energy'},
    {'ticker': 'PXD', 'name': 'Pioneer Natural Resources', 'sector': 'Energy'},
    {'ticker': 'BKR', 'name': 'Baker Hughes', 'sector': 'Energy'},
    {'ticker': 'WMB', 'name': 'Williams Companies', 'sector': 'Energy'},

    # Consumer Staples Sector
    {'ticker': 'PG', 'name': 'Procter & Gamble', 'sector': 'Consumer Staples'},
    {'ticker': 'KO', 'name': 'Coca-Cola Company', 'sector': 'Consumer Staples'},
    {'ticker': 'PEP', 'name': 'PepsiCo Inc.', 'sector': 'Consumer Staples'},
    {'ticker': 'WMT', 'name': 'Walmart Inc.', 'sector': 'Consumer Staples'},
    {'ticker': 'COST', 'name': 'Costco Wholesale Corporation', 'sector': 'Consumer Staples'},
    {'ticker': 'PM', 'name': 'Philip Morris International', 'sector': 'Consumer Staples'},
    {'ticker': 'MO', 'name': 'Altria Group', 'sector': 'Consumer Staples'},
    {'ticker': 'MDLZ', 'name': 'Mondelez International', 'sector': 'Consumer Staples'},
    {'ticker': 'CL', 'name': 'Colgate-Palmolive', 'sector': 'Consumer Staples'},
    {'ticker': 'UL', 'name': 'Unilever PLC', 'sector': 'Consumer Staples'},
    {'ticker': 'KMB', 'name': 'Kimberly-Clark Corporation', 'sector': 'Consumer Staples'},
    {'ticker': 'GIS', 'name': 'General Mills', 'sector': 'Consumer Staples'},
    {'ticker': 'KHC', 'name': 'Kraft Heinz Company', 'sector': 'Consumer Staples'},
    {'ticker': 'EL', 'name': 'Estee Lauder Companies', 'sector': 'Consumer Staples'},
    {'ticker': 'TSN', 'name': 'Tyson Foods', 'sector': 'Consumer Staples'},

    # Utilities Sector
    {'ticker': 'NEE', 'name': 'NextEra Energy', 'sector': 'Utilities'},
    {'ticker': 'DUK', 'name': 'Duke Energy Corporation', 'sector': 'Utilities'},
    {'ticker': 'D', 'name': 'Dominion Energy', 'sector': 'Utilities'},
    {'ticker': 'SO', 'name': 'Southern Company', 'sector': 'Utilities'},
    {'ticker': 'AEP', 'name': 'American Electric Power', 'sector': 'Utilities'},
    {'ticker': 'EXC', 'name': 'Exelon Corporation', 'sector': 'Utilities'},
    {'ticker': 'SRE', 'name': 'Sempra Energy', 'sector': 'Utilities'},
    {'ticker': 'ED', 'name': 'Consolidated Edison', 'sector': 'Utilities'},
    {'ticker': 'PEG', 'name': 'Public Service Enterprise', 'sector': 'Utilities'},
    {'ticker': 'XEL', 'name': 'Xcel Energy', 'sector': 'Utilities'},
    {'ticker': 'PPL', 'name': 'PPL Corporation', 'sector': 'Utilities'},
    {'ticker': 'EIX', 'name': 'Edison International', 'sector': 'Utilities'},
    {'ticker': 'ETR', 'name': 'Entergy Corporation', 'sector': 'Utilities'},
    {'ticker': 'FE', 'name': 'FirstEnergy Corp.', 'sector': 'Utilities'},
    {'ticker': 'AEE', 'name': 'Ameren Corporation', 'sector': 'Utilities'}
]

# %%
# Function to fetch historical data from Alpha Vantage
def fetch_stock_data(symbol, sector):
    """Fetches stock data using the appropriate API key for the sector."""
    api_key = api_keys.get(sector)  # Get API key for the sector
    if not api_key:
        print(f"No API key found for sector: {sector}")
        return pd.DataFrame()

    url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={api_key}'
    response = requests.get(url)
    data = response.json()

      # Check for error messages in the response
    if 'Error Message' in data:
        print(f"Error fetching data for {symbol}: {data['Error Message']}")
        return pd.DataFrame()
    elif 'Note' in data:
        print(f"Note for {symbol}: {data['Note']}") # This likely indicates rate limiting
        return pd.DataFrame()
    elif 'Time Series (Daily)' not in data:
        print(f"Unexpected response format for {symbol}: {data}")
        return pd.DataFrame()

    if 'Time Series (Daily)' in data:
        df = pd.DataFrame.from_dict(data['Time Series (Daily)'], orient='index')
        df.rename(columns={
            '1. open': 'Open',
            '2. high': 'High',
            '3. low': 'Low',
            '4. close': 'Close',
            '5. volume': 'Volume'
        }, inplace=True)
        df.index = pd.to_datetime(df.index)
        df = df[df.index >= '2020-07-01']
        df = df.apply(pd.to_numeric, errors='coerce')
        return df
    else:
        print(f"Failed to fetch data for {symbol}: {data.get('Note', 'Unknown error')}")
        return pd.DataFrame()

# %%
# Compile all data into a single DataFrame
all_data = pd.DataFrame()

for company in companies:
    symbol = company['ticker']
    name = company['name']
    sector = company['sector']

    print(f"Fetching data for {name} ({symbol}) in sector: {sector}")
    stock_data = fetch_stock_data(symbol, sector)

    if not stock_data.empty:
        stock_data['Ticker'] = symbol
        stock_data['Company Name'] = name
        stock_data['Sector'] = sector
        all_data = pd.concat([all_data, stock_data])

    # 5/min so that we don't run out of API calls to AV
    sleep(12)

# Reset index and save to CSV
all_data.reset_index(inplace=True)
all_data.rename(columns={'index': 'Date'}, inplace=True)
all_data.to_csv('stock_data_with_sectors.csv', index=False)

print("Data collection complete. Saved to stock_data_with_sectors.csv")
# Out:
# Fetching data for Johnson & Johnson (JNJ) in sector: Healthcare
# Fetching data for UnitedHealth Group (UNH) in sector: Healthcare
# Fetching data for Pfizer Inc. (PFE) in sector: Healthcare
# Fetching data for Merck & Co. (MRK) in sector: Healthcare
# Fetching data for AbbVie Inc. (ABBV) in sector: Healthcare
# Fetching data for Eli Lilly and Co. (LLY) in sector: Healthcare
# Fetching data for Thermo Fisher Scientific (TMO) in sector: Healthcare
# Fetching data for Abbott Laboratories (ABT) in sector: Healthcare
# Fetching data for Bristol-Myers Squibb (BMY) in sector: Healthcare
# Fetching data for Amgen Inc. (AMGN) in sector: Healthcare
# Fetching data for Gilead Sciences (GILD) in sector: Healthcare
# Fetching data for Novo Nordisk (NVO) in sector: Healthcare
# Fetching data for Sanofi-Aventis (SNY) in sector: Healthcare
# Fetching data for Vertex Pharmaceuticals (VRTX) in sector: Healthcare
# Fetching data for Medtronic PLC (MDT) in sector: Healthcare
# Fetching data for Apple Inc. (AAPL) in sector: Technology
# Fetching data for Microsoft Corporation (MSFT) in sector: Technology
# Fetching data for Alphabet Inc. (Class A) (GOOGL) in sector: Technology
# Fetching data for Alphabet Inc. (Class C) (GOOG) in sector: Technology
# Fetching data for Amazon.com Inc. (AMZN) in sector: Technology
# Fetching data for Meta Platforms, Inc. (META) in sector: Technology
# Fetching data for Intel Corporation (INTC) in sector: Technology
# Fetching data for Cisco Systems (CSCO) in sector: Technology
# Fetching data for NVIDIA Corporation (NVDA) in sector: Technology
# Fetching data for Oracle Corporation (ORCL) in sector: Technology
# Fetching data for Adobe Inc. (ADBE) in sector: Technology
# Fetching data for Salesforce.com Inc. (CRM) in sector: Technology
# Fetching data for IBM Corporation (IBM) in sector: Technology
# Fetching data for Texas Instruments (TXN) in sector: Technology
# Fetching data for Broadcom Inc. (AVGO) in sector: Technology
# Fetching data for Exxon Mobil Corporation (XOM) in sector: Energy
# Fetching data for Chevron Corporation (CVX) in sector: Energy
# Fetching data for ConocoPhillips (COP) in sector: Energy
# Fetching data for Schlumberger Limited (SLB) in sector: Energy
# Fetching data for EOG Resources (EOG) in sector: Energy
# Fetching data for Occidental Petroleum (OXY) in sector: Energy
# Fetching data for Phillips 66 (PSX) in sector: Energy
# Fetching data for Marathon Petroleum (MPC) in sector: Energy
# Fetching data for Valero Energy (VLO) in sector: Energy
# Fetching data for Kinder Morgan (KMI) in sector: Energy
# Fetching data for Halliburton Company (HAL) in sector: Energy
# Fetching data for Devon Energy (DVN) in sector: Energy
# Fetching data for Pioneer Natural Resources (PXD) in sector: Energy
# Fetching data for Baker Hughes (BKR) in sector: Energy
# Fetching data for Williams Companies (WMB) in sector: Energy
# Fetching data for Procter & Gamble (PG) in sector: Consumer Staples
# Fetching data for Coca-Cola Company (KO) in sector: Consumer Staples
# Fetching data for PepsiCo Inc. (PEP) in sector: Consumer Staples
# Fetching data for Walmart Inc. (WMT) in sector: Consumer Staples
# Fetching data for Costco Wholesale Corporation (COST) in sector: Consumer Staples
# Fetching data for Philip Morris International (PM) in sector: Consumer Staples
# Fetching data for Altria Group (MO) in sector: Consumer Staples
# Fetching data for Mondelez International (MDLZ) in sector: Consumer Staples
# Fetching data for Colgate-Palmolive (CL) in sector: Consumer Staples
# Fetching data for Unilever PLC (UL) in sector: Consumer Staples
# Fetching data for Kimberly-Clark Corporation (KMB) in sector: Consumer Staples
# Fetching data for General Mills (GIS) in sector: Consumer Staples
# Fetching data for Kraft Heinz Company (KHC) in sector: Consumer Staples
# Fetching data for Estee Lauder Companies (EL) in sector: Consumer Staples
# Fetching data for Tyson Foods (TSN) in sector: Consumer Staples
# Fetching data for NextEra Energy (NEE) in sector: Utilities
# Fetching data for Duke Energy Corporation (DUK) in sector: Utilities
# Fetching data for Dominion Energy (D) in sector: Utilities
# Fetching data for Southern Company (SO) in sector: Utilities
# Fetching data for American Electric Power (AEP) in sector: Utilities
# Fetching data for Exelon Corporation (EXC) in sector: Utilities
# Fetching data for Sempra Energy (SRE) in sector: Utilities
# Fetching data for Consolidated Edison (ED) in sector: Utilities
# Fetching data for Public Service Enterprise (PEG) in sector: Utilities
# Fetching data for Xcel Energy (XEL) in sector: Utilities
# Fetching data for PPL Corporation (PPL) in sector: Utilities
# Fetching data for Edison International (EIX) in sector: Utilities
# Fetching data for Entergy Corporation (ETR) in sector: Utilities
# Fetching data for FirstEnergy Corp. (FE) in sector: Utilities
# Fetching data for Ameren Corporation (AEE) in sector: Utilities
# Data collection complete. Saved to stock_data_with_sectors.csv

# %%
full_df = pd.read_csv('stock_data_with_sectors.csv')
# full_df.rename(columns={'5. volume': 'Volume'}, inplace=True)
full_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09935a66e499> in <cell line: 1>()
# ----> 1 full_df = pd.read_csv('stock_data_with_sectors.csv')
#       2 # full_df.rename(columns={'5. volume': 'Volume'}, inplace=True)
#       3 full_df.head()
#
# NameError: name 'pd' is not defined

# %%
earliest_date = full_df['Date'].min()
print(earliest_date)

#post covid, when markets returned to normal
# Out:
# 2020-07-01

# %%
ts = TimeSeries(api_key, output_format='pandas')
data, meta = ts.get_daily('IBM')
data.head()
# Out:
#             1. open   2. high    3. low  4. close  5. volume
# date
# 2024-11-08   214.16  216.7000  212.7809    213.72  3201038.0
# 2024-11-07   213.64  214.5199  211.9300    213.69  3675812.0
# 2024-11-06   213.48  214.3300  210.3700    213.60  3934386.0
# 2024-11-05   206.17  208.1150  205.5700    207.57  2441535.0
# 2024-11-04   207.65  207.7000  205.8000    206.32  2594119.0

# %%
earliest_date = data.last_valid_index()
print(earliest_date)
# Out:
# 2024-06-20 00:00:00

# %%
data_arr = data.to_numpy()
print("nump data array\n", data_arr)
# Out:
# nump data array
#  [[2.1416000e+02 2.1670000e+02 2.1278090e+02 2.1372000e+02 3.1897530e+06]
#  [2.1364000e+02 2.1451990e+02 2.1193000e+02 2.1369000e+02 3.6758120e+06]
#  [2.1348000e+02 2.1433000e+02 2.1037000e+02 2.1360000e+02 3.9343860e+06]
#  [2.0617000e+02 2.0811500e+02 2.0557000e+02 2.0757000e+02 2.4415350e+06]
#  [2.0765000e+02 2.0770000e+02 2.0580000e+02 2.0632000e+02 2.5941190e+06]
#  [2.0777000e+02 2.0984000e+02 2.0741000e+02 2.0825000e+02 3.3343080e+06]
#  [2.0413000e+02 2.0813000e+02 2.0351000e+02 2.0672000e+02 5.9252500e+06]
#  [2.0948000e+02 2.1112000e+02 2.0426000e+02 2.0490000e+02 6.9566240e+06]
